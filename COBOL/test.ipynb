# %%
import pandas as pd 
import numpy as np

# %%
df_1 = pd.read_csv("/root/Work/cdc_project/COBOL/Dice_US_jobs.csv")

# %%
df_1[df_1.job_description.apply( lambda x : "cobol" in x.lower() )]
# Out:
#       country_code  date_added             job_board  \
# 117             US  11/11/2016  https://www.dice.com
# 145             US  11/11/2016  https://www.dice.com
# 299             US   7/16/2016  https://www.dice.com
# 308             US   9/15/2016  https://www.dice.com
# 854             US   9/15/2016  https://www.dice.com
# ...            ...         ...                   ...
# 21241           US   6/20/2016  https://www.dice.com
# 21254           US   6/20/2016  https://www.dice.com
# 21259           US   6/20/2016  https://www.dice.com
# 21304           US   6/20/2016  https://www.dice.com
# 21887           US   12/9/2016  https://www.dice.com
#
#                                          job_description  \
# 117    Minimum Required Skills:Java, JavaScript, HTML...
# 145    Minimum Required Skills:Java, JavaScript, HTML...
# 299    Our client is currently seeking a Telcordia Te...
# 308    Minimum Required Skills:Java, CA PLEX/Obsydian...
# ...

# %%
df_2[df_2.job_description.apply( lambda x : "cobol" in x.lower() )]
# Out:
#                         country country_code date_added has_expired  \
# 810    United States of America           US        NaN          No
# 898    United States of America           US        NaN          No
# 1068   United States of America           US  6/24/2016          No
# 1586   United States of America           US        NaN          No
# 3697   United States of America           US        NaN          No
# 4218   United States of America           US        NaN          No
# 5179   United States of America           US        NaN          No
# 10429  United States of America           US        NaN          No
# 10454  United States of America           US        NaN          No
# 11344  United States of America           US   6/7/2016          No
# 11896  United States of America           US        NaN          No
# 15739  United States of America           US        NaN          No
# 15799  United States of America           US        NaN          No
# ...
